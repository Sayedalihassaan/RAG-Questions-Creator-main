# %%
import os 
from dotenv import load_dotenv 
import warnings 
warnings.filterwarnings("ignore") 
from pprint import pprint 
from langchain.document_loaders import PyPDFLoader , DirectoryLoader 
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI 
from langchain.text_splitter import RecursiveCharacterTextSplitter 
from langchain.prompts import PromptTemplate 
from langchain.chains.question_answering import load_qa_chain 
from langchain_community.vectorstores import FAISS

# %%
load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# #### Load Model Gemini

# %%
def load_model(name_model):
    
    llm = ChatGoogleGenerativeAI(
        model=name_model,
        temperature=0.2,
        google_api_key=GOOGLE_API_KEY
    )
    return llm

model = load_model("gemini-1.5-flash")

# %%
model.invoke("Hi!")
# Out:
# AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run--8bb593b9-21da-4037-add0-ce59a1ee3360-0', usage_metadata={'input_tokens': 2, 'output_tokens': 11, 'total_tokens': 13, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# #### Load Data

# %%
def data_extraction(path_data):

    if not os.path.exists(path_data):
        raise FileNotFoundError(f"The directory {path_data} does not exist.")
    
    loader = DirectoryLoader(path=path_data, glob="*.pdf", loader_cls=PyPDFLoader, show_progress=True)
    documents = loader.load()
    
    print(f"Number of documents loaded: {len(documents)}")
    if not documents:
        print(f"No PDF files found in {path_data}")
    
    return documents

extracted_data = data_extraction("../DataSets/")
# Out:
# 100%|██████████| 1/1 [00:04<00:00,  4.25s/it]
# Number of documents loaded: 132

# %% [markdown]
# #### Text Chunking

# %%
def text_chunking(extracted_data):
    text_split = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=200)
    chunks = text_split.split_documents(extracted_data)
    return chunks

# Extract data and create chunks
text_chunks = text_chunking(extracted_data)

# %%
print(f"Number of chunks: {len(text_chunks)}")
# Out:
# Number of chunks: 131

# %%
for i, chunk in enumerate(text_chunks):
            print(f"Chunk {i+1} content preview: {chunk.page_content[:100]}...")
# Out:
# Chunk 1 content preview: Learn	Python	in	One	Day	and	Learn	It	Well
# Python	for	Beginners	with	Hands-on	Project
# The	only	book	y...
# Chunk 2 content preview: In	addition,	as	Richard	Branson	puts	it:	"The	best	way	of	learning	about
# anything	is	by	doing".	At	t...
# Chunk 3 content preview: Table	of	Contents
#
# Chapter	1:	Python,	what	Python?
# What	is	Python?
# Why	Learn	Python?
# Chapter	2:	Get...
# Chunk 4 content preview: Condition	Statements
# If	Statement
# Inline	If
# For	Loop
# While	Loop
# Break
# Continue
# Try,	Except
# Chapter	7...
# Chunk 5 content preview: Appendix	D:	Working	With	Dictionaries
# Appendix	E:	Project	Answers
# One	Last	Thing…...
# Chunk 6 content preview: Chapter	1:	Python,	what	Python?
#
# Welcome	to	the	exciting	world	of	programming.	I'm	so	glad	you	pick...
# Chunk 7 content preview: What	is	Python?
#
# Python	is	a	widely	used	high-level	programming	language	created	by
# Guido	van	Rossu...
# Chunk 8 content preview: Why	Learn	Python?
#
# There	are	a	large	number	of	high	level	programming	languages	available,
# such	as	...
# Chunk 9 content preview: Chapter	2:	Getting	ready	for	Python
# Installing	the	Interpreter
#
# Before	we	can	write	our	first	Pytho...
# Chunk 10 content preview: computer.	The	installer	to	use	depends	on	two	factors:
#
# 1.	The	operating	system	(Windows,	Mac	OS,	o...
# Chunk 11 content preview: Using	the	Python	Shell,	IDLE	and	Writing	our
# FIRST	program
#
# We’ll	be	writing	our	code	using	the	IDL...
# Chunk 12 content preview: When	you	type
# 2+3
# ,	you	are	issuing	a	command	to	the	Shell,	asking	it	to
# evaluate	the	value	of	2+3....
# Chunk 13 content preview: The	line
# #Prints	the	Words	“Hello	World”
# 	(in	red)	is	actually	not
# part	of	the	program.	It	is	a	com...
# Chunk 14 content preview: the	print	statements.	Instead	of	writing
# print	‘Hello	World’
# ,	you
# have	to	write
# print	(‘Hello	Wor...
# Chunk 15 content preview: Chapter	3:	The	World	of	Variables	and	Operators
#
# Now	that	we’re	done	with	the	introductory	stuff,	l...
# Chunk 16 content preview: What	are	variables?
#
# Variables	are	names	given	to	data	that	we	need	to	store	and	manipulate
# in	our	...
# Chunk 17 content preview: Naming	a	Variable
#
# A	variable	name	in	Python	can	only	contain	letters	(a	-	z,	A	-	B),	numbers
# or	un...
# Chunk 18 content preview: The	Assignment	Sign
#
# Note	that	the	=	sign	in	the	statement
# userAge	=	0
# 	has	a	different
# meaning	fr...
# Chunk 19 content preview: the	third	line	from
# x	=	y
# 	to
# y	=	x
# .	Mathematically,	x	=	y	and	y	=	x	mean
# the	same	thing.	However...
# Chunk 20 content preview: Basic	Operators
#
# Besides	assigning	a	variable	an	initial	value,	we	can	also	perform	the
# usual	mathe...
# Chunk 21 content preview: More	Assignment	Operators
#
# Besides	the	=	sign,	there	are	a	few	more	assignment	operators	in	Python
# ...
# Chunk 22 content preview: Chapter	4:	Data	Types	in	Python
#
# In	this	chapter,	we’ll	first	look	at	some	basic	data	types	in	Pyth...
# Chunk 23 content preview: Integers
#
# Integers	are	numbers	with	no	decimal	parts,	such	as	-5,	-4,	-3,	0,	5,	7	etc.
#
# To	declare...
# Chunk 24 content preview: Float
#
# Float	refers	to	numbers	that	have	decimal	parts,	such	as	1.234,	-0.023,
# 12.01.
#
# To	declare	...
# Chunk 25 content preview: String
#
# String	refers	to	text.
#
# To	declare	a	string,	you	can	either	use
# variableName	=	‘initial
# v...
# Chunk 26 content preview: Formatting	Strings	using	the	%	Operator
#
# Strings	can	also	be	formatted	using	the	%	operator.	This	g...
# Chunk 27 content preview: round	brackets.	If	we	run	the	code,	we’ll	get	the	output	below.
#
# The	price	of	this	Apple	laptop	is	...
# Chunk 28 content preview: use,	followed	by	a	colon.	After	the	colon,	we	write	the	formatter.	There
# should	not	be	any	spaces	wi...
# Chunk 29 content preview: 1299,	1.235235245)
#
# Here	we	do	not	have	to	specify	the	position	of	the	parameters.	The
# interpreter	...
# Chunk 30 content preview: You	can	use	the	Python	Shell	to	experiment	with	the
# format()
# 	method.
# Try	typing	in	various	strings...
# Chunk 31 content preview: Type	Casting	In	Python
#
# Sometimes	in	our	program,	it	is	necessary	for	us	to	convert	from	one
# data	t...
# Chunk 32 content preview: List
#
# List	refers	to	a	collection	of	data	which	are	normally	related.	Instead	of
# storing	these	data...
# Chunk 33 content preview: If	you	write
# userAge3	=	userAge[2:4]
# ,	you	are	assigning	items	with
# index	2	to	index	4-1	from	the	l...
# Chunk 34 content preview: deleted)
# To	fully	appreciate	the	workings	of	a	list,	try	running	the	following
# program.
#
# #declaring...
# Chunk 35 content preview: #remove	the	sixth	item	from	myList	and	print	the
# updated	list	del
# myList[5]
#
#
#
# 			...
# Chunk 36 content preview: Tuple
#
# Tuples	are	just	like	lists,	but	you	cannot	modify	their	values.	The	initial
# values	are	the	v...
# Chunk 37 content preview: Dictionary
#
# Dictionary	is	a	collection	of	related	data	PAIRS.	For	instance,	if	we	want
# to	store	the...
# Chunk 38 content preview: You’ll	get	the	value
# 51
# .
#
# To	modify	items	in	a	dictionary,	we	write
# dictionaryName[dictionary	key...
# Chunk 39 content preview: print(myDict)
#
#
#
#
#
# #You’ll	get	{2.5:	'Two	Point	Five',	3:	'+',	'One':
# ...
# Chunk 40 content preview: can	refer	to	Appendix	D....
# Chunk 41 content preview: Chapter	5:	Making	Your	Program	Interactive
#
# Now	that	we’ve	covered	the	basics	of	variables,	let	us	...
# Chunk 42 content preview: Input()
#
# In	the	example	above,	we	used	the
# input()
# 	function	twice	to	get	our
# user’s	name	and	age....
# Chunk 43 content preview: Print()
#
# The
# print()
# function	is	used	to	display	information	to	users.	It	accepts
# zero	or	more	ex...
# Chunk 44 content preview: write
#
# print	(“Hello	World,	my	name	is	{}	and	I	am	{}	years
# old”.format(myName,	myAge))
#
# The
# prin...
# Chunk 45 content preview: Triple	Quotes
#
# If	you	need	to	display	a	long	message,	you	can	use	the	triple-quote
# symbol	(‘’’	or	“...
# Chunk 46 content preview: Escape	Characters
#
# Sometimes	we	may	need	to	print	some	special	“unprintable”	characters
# such	as	a	t...
# Chunk 47 content preview: \’	(Print	single	quote,	so	that	the	single	quote	does	not	signal	the	end	of
# the	string)
#
# >>>	print	...
# Chunk 48 content preview: Chapter	6:	Making	Choices	and	Decisions
#
# Congratulations,	you’ve	made	it	to	the	most	interesting	ch...
# Chunk 49 content preview: Condition	Statements
#
# All	control	flow	tools	involve	evaluating	a	condition	statement.	The
# program	...
# Chunk 50 content preview: The
# and
# 	operator	returns
# True
# 	if	all	conditions	are	met.	Else	it	will	return
# False
# .	For	instanc...
# Chunk 51 content preview: If	Statement
#
# The
# if
# 	statement	is	one	of	the	most	commonly	used	control	flow
# statements.	It	allow...
# Chunk 52 content preview: Next	the	statement
# if	userInput	==	"1":
# 	compares	the
# userInput
# 	variable	with	the	string	“1”.	If	t...
# Chunk 53 content preview: Inline	If
#
# An	inline
# if
# 	statement	is	a	simpler	form	of	an
# if
# 	statement	and	is	more
# convenient	i...
# Chunk 54 content preview: For	Loop
#
# Next,	let	us	look	at	the
# for
# 	loop.	The
# for
# 	loop	executes	a	block	of	code
# repeatedly	u...
# Chunk 55 content preview: If	you	run	the	program,	you’ll	get
#
# cats
# dogs
# rabbits
# hamsters
#
# We	can	also	display	the	index	of	t...
# Chunk 56 content preview: l
# o
#
# Looping	through	a
# sequence	of	numbers
#
# To	loop	through	a	sequence	of	numbers,	the	built-in
# ...
# Chunk 57 content preview: range(3,	10)
# 	will	generate	[3,	4,	5,	6,	7,	8,	9]
# range(4,	10,	2)
# will	generate	[4,	6,	8]
#
# To	see	...
# Chunk 58 content preview: While	Loop
#
# The	next	control	flow	statement	we	are	going	to	look	at	is	the
# while
# loop.	Like	the	na...
# Chunk 59 content preview: value	back	to
# counter
# ,	overwriting	the	original	value.
#
# We	need	to	decrease	the	value	of
# counter...
# Chunk 60 content preview: Break
#
# When	working	with	loops,	sometimes	you	may	want	to	exit	the	entire	loop
# when	a	certain	condi...
# Chunk 61 content preview: Continue
#
# Another	useful	keyword	for	loops	is	the
# continue
# 	keyword.	When	we
# use
# continue
# ,	the	r...
# Chunk 62 content preview: Try,	Except
#
# The	final	control	statement	we’ll	look	at	is	the
# try,	except
# 	statement.
# This	stateme...
# Chunk 63 content preview: print	("Unknown	error:	",	e)
# The	list	below	shows	the	various	outputs	for	different	user	inputs.	>>>...
# Chunk 64 content preview: IOError:
# Raised	when	an	I/O	operation	(such	as	the	built-in
# open()
# 	function)	fails
# for	an	I/O-rela...
# Chunk 65 content preview: attempt	to	catch	any	unanticipated	errors....
# Chunk 66 content preview: Chapter	7:	Functions	and	Modules
#
# In	our	previous	chapters,	we’ve	briefly	mentioned	functions	and	m...
# Chunk 67 content preview: What	are	Functions?
#
# Functions	are	simply	pre-written	codes	that	perform	a	certain	task.	For	an
# ana...
# Chunk 68 content preview: Defining	Your	Own	Functions
#
# We	can	define	our	own	functions	in	Python	and	reuse	them	throughout
# th...
# Chunk 69 content preview: then	exit.
#
# To	use	this	function,	we	type
# checkIfPrime(13)
# 	and	assign	it	to	a
# variable	like	this
# ...
# Chunk 70 content preview: Variable	Scope
#
# An	important	concept	to	understand	when	defining	a	function	is	the
# concept	of	varia...
# Chunk 71 content preview: Global	Variable
# Local	Variable
#
# OUTSIDE	THE	FUNCTION
# Global	Variable
# NameError:	name	'message2'	is	...
# Chunk 72 content preview: Variable	(shares	same	name	as	a	global	variable)"
# 	as	it
# is	printing	the	local	variable.	When	we	pri...
# Chunk 73 content preview: Importing	Modules
#
# Python	comes	with	a	large	number	of	built-in	functions.	These	functions
# are	save...
# Chunk 74 content preview: Creating	our	Own	Module
#
# Besides	importing	built-in	modules,	we	can	also	create	our	own	modules.
# Th...
# Chunk 75 content preview: useCheckIfPrime.py
# 	in	different	folders.	You	are	going	to	have	to	add
# some	codes	to
# useCheckIfPrim...
# Chunk 76 content preview: Chapter	8:	Working	with	Files
#
# Cool!	We’ve	come	to	the	last	chapter	of	the	book	before	the	project....
# Chunk 77 content preview: Opening	and	Reading	Text	Files
#
# The	first	type	of	file	we	are	going	to	read	from	is	a	simple	text	f...
# Chunk 78 content preview: named	‘PythonFiles’	in	your	C	drive,	you	have	to	write
# ‘C:\\PythonFiles\\myfile.txt’
# 	(with	double	b...
# Chunk 79 content preview: Python	for	Beginners	with	Hands-on	Project
#
# You’ll	notice	that	a	line	break	is	inserted	after	each	...
# Chunk 80 content preview: Using	a	For	Loop	to	Read	Text	Files
#
# In	addition	to	using	the
# readline()
# 	method	above	to	read	a	t...
# Chunk 81 content preview: Writing	to	a	Text	File
#
# Now	that	we’ve	learned	how	to	open	and	read	a	file,	let’s	try	writing	to	it...
# Chunk 82 content preview: Opening	and	Reading	Text	Files	by	Buffer	Size
#
# Sometimes,	we	may	want	to	read	a	file	by	buffer	size...
# Chunk 83 content preview: characters.	Here’s	a	segment	of	what	you’ll	get.
#
# Learn	Pyth
# on	in	One
# Day	and	Le
# arn	It	Wel...
# Chunk 84 content preview: Opening,	Reading	and	Writing	Binary	Files
#
# Binary	files	refer	to	any	file	that	contains	non-text,	s...
# Chunk 85 content preview: Deleting	and	Renaming	Files
#
# Two	other	useful	functions	we	need	to	learn	when	working	with	files	ar...
# Chunk 86 content preview: Project:	Math	and	BODMAS
#
# Congratulations!	We’ve	now	covered	enough	fundamentals	of	Python
# (and	pro...
# Chunk 87 content preview: Part	1:	myPythonFunctions.py
#
# We	will	be	writing	two	files	for	our	programs.	The	first	file	is
# myPy...
# Chunk 88 content preview: Darren,	129
#
# Each	line	records	the	information	of	one	user.	The	first	value	is	the	user’s
# username	...
# Chunk 89 content preview: The	second	method	is	to	use	a
# try,	except
# 	statement	to	handle	the
# IOError
# .	To	do	that,	we	need	to...
# Chunk 90 content preview: before	writing	it	to	the	temporary	file.
#
# For	instance,	if	the	parameters	provided	to	the	function	...
# Chunk 91 content preview: We	shall	name	the	two	lists
# operandList
# 	and
# operatorList
# .
#
# operandList
# 	should	store	five	numbe...
# Chunk 92 content preview: The	better	alternative	is	to	use	a
# for
# 	loop.
#
# Try	using	a
# for
# 	loop	to	accomplish	the	same	task....
# Chunk 93 content preview: To	prevent	this	problem,	we’re	going	to	modify	our	code	so	that	we	do	not
# get	two	consecutive	**	sig...
# Chunk 94 content preview: We	should	now	have	a	mathematical	expression	as	a	string,	assigned	to
# the	variable
# questionString
# ....
# Chunk 95 content preview: For	step	2,	you	can	use	the
# input()
# 	function	to	accept	user	input.
#
# For	step	3,	you	should	use	an...
# Chunk 96 content preview: Try	this	exercise.	Once	you	are	done,	we	can	proceed	to	Part	2	where
# we	write	the	actual	program....
# Chunk 97 content preview: Part	2:	mathGame.py
#
# Congratulations	for	completing	Part	1	and	welcome	to	Part	2.	Part	2	is
# going	t...
# Chunk 98 content preview: Step	2:
# Next,	using	a
# while
# 	loop,	compare
# userChoice
# 	with	a	string	of	your
# choice,	say	“-1”.	If	...
# Chunk 99 content preview: Challenge	Yourself
#
# We’ve	come	to	the	end	of	this	chapter	and	hopefully	you	have
# successfully	coded...
# Chunk 100 content preview: The	last	challenge	exercise	is	the	most	difficult.
#
# So	far,	brackets	are	missing	in	the	questions	g...
# Chunk 101 content preview: Thank	You
#
# We’ve	come	to	the	end	of	the	book.	Thank	you	for	reading	this	book	and	I
# hope	you	have	e...
# Chunk 102 content preview: Appendix	A:	Working	With	Strings
#
# Note:	The	notation	[start,	[end]]	means
# start
# 	and
# end
# 	are	opt...
# Chunk 103 content preview: endswith	(suffix,	[start,	[end]])
# Return	True	if	the	string	ends	with	the	specified
# suffix
# ,	otherw...
# Chunk 104 content preview: #	check	the	entire	string
# ‘This	is	a	string’.find(‘s’)
# =>	3
#
# #	check	from	index	4	to	end	of	string	...
# Chunk 105 content preview: ‘1234’.isalnum()
# =>	True
#
# isalpha()
#
# Return	true	if	all	characters	in	the	string	are	alphabetic	an...
# Chunk 106 content preview: ‘abcd1234’.isdigit()
# =>	False
#
# ‘abcd’.isdigit()
# =>	False
#
# ‘1	2	3	4’.isdigit()
# =>	False
#
# islower()...
# Chunk 107 content preview: ‘	’.isspace()
# =>	True
#
# ‘a	b’.isspace()
# =>	False
#
# istitle()
#
# Return	true	if	the	string	is	a	titlec...
# Chunk 108 content preview: =>	False
#
# join()
#
# Return	a	string	in	which	the	parameter	provided	is	joined	by	a	separator.
#
# [Exa...
# Chunk 109 content preview: Return	a	copy	of	the	string	with	all	occurrences	of	substring	old	replaced
# by	new.
# count
# 	is	optiona...
# Chunk 110 content preview: =>	['This',	'is',	'a',	'string']
#
# #	Only	do	2	splits
# ‘This,	is,	a,	string’.split(‘,’	2)	=>	['This',...
# Chunk 111 content preview: Return	True	if	string	starts	with	the	prefix,	otherwise	return	False.
# prefix
# 	can	also	be	a	tuple	of...
# Chunk 112 content preview: #	Strip	whitespaces
# ‘
# This	is	a	string
# ’.strip()	=>	'This	is	a	string'
#
# #	Strip	‘s’.	Nothing	is	r...
# Chunk 113 content preview: Appendix	B:	Working	With	Lists
#
# =>	marks	the	start	of	the	output
# append(	)
#
# Add	item	to	the	end	of...
# Chunk 114 content preview: #delete	items	from	index	2	to	end	del	myList	[2:]
# print	(myList)
# =>	[‘i’,	‘j’]
#
# extend(	)
#
# Combine...
# Chunk 115 content preview: myList	=	[‘a’,	‘b’,	‘c’,	‘d’,	‘e’]
# myList.insert(1,	‘Hi’)	print	(myList)
# =>	[‘a’,	‘Hi’,	‘b’,	‘c’,	‘d...
# Chunk 116 content preview: Remove	an	item	from	a	list.	Requires	the	value	of	the	item	as	the
# parameter.
#
# [Example]
#
# myList	=	...
# Chunk 117 content preview: Return	a	new	sorted	list	without	sorting	the	original	list.
# Requires	a	list	as	the	parameter
# [Exampl...
# Chunk 118 content preview: =>	['a',	'b',	'c',	'd',	'a',	'b',	'c',	'd',	'a',	'b',	'c',	'd']
#
# print	(myList)
# =>	[‘a’,	‘b’,	‘c’,	...
# Chunk 119 content preview: Appendix	C:	Working	With	Tuples
#
# =>	marks	the	start	of	the	output
# del
#
# Delete	the	entire	tuple
# [Ex...
# Chunk 120 content preview: Concatenate	Tuples
# [Example]
#
# myTuple	=	(‘a’,	‘b’,	‘c’,	‘d’)	print	(myTuple	+	(‘e’,
# ‘f’))	=>	(‘a’,	...
# Chunk 121 content preview: Appendix	D:	Working	With	Dictionaries
#
# =>	marks	the	start	of	the	output
# clear(	)
#
# Removes	all	elem...
# Chunk 122 content preview: dic1	=	{1:	‘one’,	2:	‘two’}
# dic1.get(1)
# =>	‘one’
#
# dic1.get(5)
# =>	None
#
# dic1.get(5,	“Not	Found”)	=>...
# Chunk 123 content preview: dic1	=	{1:	‘one’,	2:	‘two’}
# dic1.items()
# =>	dict_items([(1,	'one'),	(2,	'two')])
# keys(	)
#
# Returns	l...
# Chunk 124 content preview: values(	)
#
# Returns	list	of	the	dictionary's	values
# [Example]
#
# dic1	=	{1:	‘one’,	2:	‘two’}
# dic1.val...
# Chunk 125 content preview: Appendix	E:	Project	Answers
#
# Exercise	1
#
# from	random	import	randint
# from	os	import	remove,	rename
# ...
# Chunk 126 content preview: else:
# input	=	open('userScores.txt',	'r')
# output	=	open('userScores.tmp',	'w')
# for	line	in	input:
# co...
# Chunk 127 content preview: operatorList[index]	=	operator
# questionString	=	str(operandList[0])
#
# for	index	in	range(1,	5):
# 				...
# Chunk 128 content preview: However,	if	the	previous	symbol	is	‘**’,	the	else	statement	(
# operator	=
# operatorDict[randint(1,	3)]...
# Chunk 129 content preview: Challenge	Yourself
#
# You	only	need	to	change	the	function
# generateQuestion()
# 	for	all	the
# challenge...
# Chunk 130 content preview: if	openBracket	==	0:
#
# questionString	=
# '('	+	str(operandList[0])
# else:
#
# questionStrin...
# Chunk 131 content preview: One	Last	Thing…
#
# When	you	turn	the	page,	Amazon	will	prompt	you	to	rate	this	book	and
# share	your	th...

# %% [markdown]
# #### Embedding model

# %%
embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-001" , google_api_key=GOOGLE_API_KEY)

# %%
def vector_store(text_chunks : list[str]) :
    text_chunks = [i.page_content for i in text_chunks]
    vector_db = FAISS.from_texts(texts=text_chunks , embedding=embedding)
    vector_db = vector_db.save_local(folder_path="faiss-index")
    return vector_db

vector_db = vector_store(text_chunks=text_chunks)

# %% [markdown]
# ### Pipeline for Questions Generation

# %%
def user_query(question, num_questions, difficulty_level, question_types, include_answers):

    embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-001", google_api_key=GOOGLE_API_KEY)
    
    db = FAISS.load_local(
        folder_path="faiss-index",
        embeddings=embedding,
        allow_dangerous_deserialization=True
    )
    
    docs = db.similarity_search(query=question, k=10)
    

    chain_input = {
        "input_documents": docs,
        "input": question,
        "num_questions": num_questions,
        "difficulty_level": difficulty_level,
        "question_types": question_types,
        "include_answers": include_answers
    }

    # Define exam prompt
    exam_prompt = """You are a knowledgeable and professional AI assistant that specializes in generating high-quality exam questions.

                    Your role is to:

                    1. Generate clear, accurate, and well-structured exam questions based on the provided context and requirements.
                    2. Ensure that questions are relevant to the given subject, topic, and difficulty level.
                    3. Vary the question types if requested (e.g., multiple choice, true/false, short answer, essay).
                    4. Provide correct answers or model answers if specified.
                    5. Follow academic standards and avoid overly simplistic or overly complex wording unless specified.
                    6. If context is not enough to generate meaningful questions, acknowledge the limitation and ask for more detail.

                    Remember:
                    - Do not make up unrelated information.
                    - Stick closely to the topic and subject area.
                    - Maintain clarity and educational value in all questions.
                    - Avoid repetition unless explicitly instructed.
                    - Ensure consistency with the question format and style.
                    - Do not put words in " " or ' '

                    Context:
                    {context}

                    Instructions:
                    - Number of Questions: {num_questions} and print them under each other
                    - Difficulty Level: {difficulty_level}
                    - Question Type(s): {question_types}
                    - Include Answers: {include_answers}

                    Now, generate the questions based on the above."""


    exam_prompt_template = PromptTemplate(
        input_variables=["context", "num_questions", "difficulty_level", "question_types", "include_answers"],
        template=exam_prompt
    )

    
    model = ChatGoogleGenerativeAI(model="gemini-1.5-flash", google_api_key=GOOGLE_API_KEY)

    
    chain = load_qa_chain(llm=model, prompt=exam_prompt_template)

    
    response = chain(chain_input, return_only_outputs=True)

    return response["output_text"]


user_inputs = {
    "num_questions": "50",
    "difficulty_level": "Medium",
    "question_types": "essay",
    "include_answers": "Yes"
}


try:
    response = user_query(
        question="Give me Questions on Chapter 3 only",
        num_questions=user_inputs["num_questions"],
        difficulty_level=user_inputs["difficulty_level"],
        question_types=user_inputs["question_types"],
        include_answers=user_inputs["include_answers"]
    )
    
    
    print(response)

except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\756514030.py:64: LangChainDeprecationWarning: This class is deprecated. See the following migration guides for replacements based on `chain_type`:
# stuff: https://python.langchain.com/docs/versions/migrating_chains/stuff_docs_chain
# map_reduce: https://python.langchain.com/docs/versions/migrating_chains/map_reduce_chain
# refine: https://python.langchain.com/docs/versions/migrating_chains/refine_chain
# map_rerank: https://python.langchain.com/docs/versions/migrating_chains/map_rerank_docs_chain
#
# See also guides on retrieval and question-answering here: https://python.langchain.com/docs/how_to/#qa-with-rag
#   chain = load_qa_chain(llm=model, prompt=exam_prompt_template)
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\756514030.py:67: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = chain(chain_input, return_only_outputs=True)
# Given the provided text, generating 50 distinct essay questions of medium difficulty is challenging. The text snippets focus on specific coding tasks and concepts within a Python programming tutorial, rather than a broad range of topics suitable for 50 unique essay questions.  The information is insufficient to create such a large number of diverse, medium-difficulty essay questions.
#
#
# To generate 50 meaningful essay questions, I need significantly more context.  Please provide a more comprehensive syllabus or textbook chapters that cover the material.  This would allow for the creation of questions covering various aspects of Python programming, file handling, data structures, and problem-solving techniques illustrated in the provided excerpts.
#
#
# However, I can offer a few example essay questions based on the limited context:
#
#
# 1. **Essay Question:**  Describe the process of updating user scores in the `userScores.txt` file, explaining the roles of `userScores.txt`, `userScores.tmp`, the `updateUserPoints` function, and the file handling operations involved.  Discuss the potential error handling needed and how it might be implemented.
#
#    **Answer:** The process involves reading the existing `userScores.txt` file.  If a new user is being added (`newUser` is True), the new score is appended to the file. If an existing user's score needs updating, the program creates a temporary file (`userScores.tmp`). It iterates through `userScores.txt`, updating the line for the specified user. The updated lines are written to `userScores.tmp`. Then, `userScores.txt` is deleted, and `userScores.tmp` is renamed to `userScores.txt`.  Error handling should include checking for the existence of `userScores.txt` (handling `IOError`) and validating the input score to prevent data corruption.  Robust error messages should be displayed to the user.
#
#
# 2. **Essay Question:** Analyze the provided code snippet for `generateQuestion()`. Explain the purpose of each variable (operandList, operatorList, operatorDict), the logic behind generating random operands and operators, and the potential limitations of this approach in generating diverse and mathematically challenging questions.  Suggest improvements to enhance the complexity and variety of questions generated.
#
#    **Answer:** `operandList` stores the random integer operands, `operatorList` stores the randomly selected operators, and `operatorDict` maps integer keys to arithmetic operators. The code generates random operands between 1 and 9 and randomly chooses operators (+, -, *, /).  A limitation is the simplicity of the questions; they lack parentheses and are limited to single-digit operands.  Improvements include incorporating parentheses to create more complex expressions, allowing for larger operands, and adding more operators (e.g., exponentiation, modulo).  The use of recursion could also significantly improve the difficulty.
#
#
# 3. **Essay Question:**  Discuss the advantages and disadvantages of using Python 3 over Python 2 for programming. Based on the text, explain why the author chose Python 3 for this tutorial and how this choice might affect programmers familiar with Python 2.
#
#    **Answer:** Python 3 offers improved readability, eliminates many quirks that trip up beginners, and is the present and future of the language.  Python 2, while still used, is considered legacy. The author's choice simplifies learning for beginners.  Programmers familiar with Python 2 will find about 90% similarity, making the transition relatively smooth, although some syntax differences and library changes might require adjustments.
#
#
# To obtain 50 questions, please supply more comprehensive material.  I can then tailor questions to specific chapters, algorithms, and coding challenges within the tutorial.

# %% [markdown]
# ## END
